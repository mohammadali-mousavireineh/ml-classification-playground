# %% [markdown]
# # Baseline Classification Notebook
#
# This notebook is for quick checks before moving experiments into the main IoT/Windows project.

# %%
import pandas as pd

df = pd.read_csv('../data/sample_iot_windows.csv')
df.head()

# %%
df['label'].value_counts()

# %%
df.describe(include='all')

# %% [markdown]
# ## Run baseline models
#
# The actual code is kept in `src/` so it can be reused outside notebooks.

# %%
import sys
sys.path.append('..')

from ml_playground.train_baselines import run_baseline_experiment

results = run_baseline_experiment(
    data_path='../data/sample_iot_windows.csv',
    target='label',
    output_dir='../reports'
)
results
